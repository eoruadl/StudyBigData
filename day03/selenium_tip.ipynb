# %%
import time
import requests
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sn
import pandas as pd

from selenium import webdriver
from matplotlib import rc
from bs4 import BeautifulSoup
from urllib.request import urlopen

# %%
options = webdriver.ChromeOptions()
options.add_experimental_option("excludeSwitches", ["enable-logging"])
wd = webdriver.Chrome('./chromedriver.exe', options=options)
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_7108\3449289060.py:3: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   wd = webdriver.Chrome('./chromedriver.exe', options=options)

# %%
star_url = 'https://www.starbucks.co.kr/store/store_map.do'
wd.get(star_url)

# %%
# selenium 4 버전 변경되면서 함수원형 수정됨
# 새 패키지 추가
from selenium.webdriver.common.by import By

# %%
# wd.find_element_by_xpath('//*[@id="container"]/div/form/fieldset/div/section/article[1]/article/header[2]/h3/a').click()
wd.find_element(By.XPATH, '//*[@id="container"]/div/form/fieldset/div/section/article[1]/article/header[2]/h3/a').click()
time.sleep(2)
wd.find_element(By.XPATH, '//*[@id="container"]/div/form/fieldset/div/section/article[1]/article/article[2]/div[1]/div[2]/ul/li[1]/a').click()
time.sleep(2)
wd.find_element(By.XPATH, '//*[@id="mCSB_2_container"]/ul/li[1]/a').click()

# %%
req = wd.page_source
soup = BeautifulSoup(req, "html.parser")
info = soup.find("div", id = "mCSB_3_container").find_all("li", class_ = 'quickResultLstCon')
len(info), info[0]
# Out:
# (588,
#  <li class="quickResultLstCon" data-code="3762" data-hlytag="null" data-index="0" data-lat="37.501087" data-long="127.043069" data-name="역삼아레나빌딩" data-storecd="1509" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="역삼아레나빌딩" data-store="1509" data-yn="N">역삼아레나빌딩  </strong> <p class="result_details">서울특별시 강남구 언주로 425 (역삼동)<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>)

# %%
name = info[0].find("strong").text.strip()
address = info[0].find(class_="result_details").text.strip()[:-9]
place = address.split(" ")[1]

name, address, place
# Out:
# ('역삼아레나빌딩', '서울특별시 강남구 언주로 425 (역삼동)', '강남구')

# %%
star_info = []
for item in info :
    name = item.find("strong").text.strip()
    address = item.find(class_="result_details").text.strip()[:-9]
    place = address.split(" ")[1]
   
    data = {
        "가게명" : name,
        "주소" : address,
        "구" : place
    }
    star_info.append(data)
len(star_info)
# Out:
# 588

# %%
df_star = pd.DataFrame(star_info, columns = ['가게명', '구', '주소'])
df_star.tail()
# Out:
#       가게명    구                                     주소
# 583  중랑구청  중랑구                       서울특별시 중랑구 신내로 72
# 584  사가정역  중랑구                      서울특별시 중랑구 면목로 310
# 585   상봉역  중랑구                서울특별시 중랑구 망우로 307 (상봉동)
# 586    묵동  중랑구  서울특별시 중랑구 동일로 952 (묵동, 로프트원 태릉입구역) 1층
# 587   중화역  중랑구                     서울특별시 중랑구 봉화산로 35

# %%
gu_list = list(set(df_star["구"]))
gu_list
# Out:
# ['동대문구',
#  '구로구',
#  '강남구',
#  '성북구',
#  '강북구',
#  '영등포구',
#  '송파구',
#  '서초구',
#  '노원구',
#  '성동구',
#  '강서구',
#  '마포구',
#  '관악구',
#  '광진구',
#  '은평구',
#  '용산구',
#  '금천구',
#  '도봉구',
#  '중랑구',
#  '중구',
#  '양천구',
#  '동작구',
#  '종로구',
#  '서대문구',
#  '강동구']

# %%
edi_url = "https://www.ediya.com/contents/find_store.html"
driver = webdriver.Chrome("./chromedriver.exe", options=options)
driver.get(edi_url)
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_7108\1177500784.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome("./chromedriver.exe", options=options)

# %%
# 이건 안됨

driver.find_element_by_xpath('//*[@id="contentWrap"]/div[3]/div/div[1]/ul/li[2]/a').click()
driver.find_element_by_xpath('//*[@id="keyword"]').clear
driver.find_element_by_xpath('//*[@id="keyword"]').send_keys("서울 강남구")
driver.find_element_by_xpath('//*[@id="keyword_div"]/form/button').click()

html = driver.page_source
soup = BeautifulSoup(html, "html.parser")

info = soup.find("ul", id = "placesList").find_all("li", class_='item')

info

# %%
edi_info = []



for gu in gu_list:
    driver.find_element(By.XPATH, '//*[@id="contentWrap"]/div[3]/div/div[1]/ul/li[2]/a').click()
    driver.find_element(By.XPATH, '//*[@id="keyword"]').clear
    driver.find_element(By.XPATH, '//*[@id="keyword"]').send_keys("서울 " + gu)
    driver.find_element(By.XPATH, '//*[@id="keyword_div"]/form/button').click()
    
    html = driver.page_source
    soup = BeautifulSoup(html, "html.parser")
    
    info = soup.find("ul", id = "placesList").find_all("li", class_='item')
    
    for item in info:
        name = item.find("dt").text
        address = item.find("dd").text.strip()
        place = address.split(" ")[1]
        

        data = {
            "가게명" : name,
            "구" : place,
            "주소" : address,
        }
        edi_info.append(data)
 
len(edi_info)
# Out:
# 707

# %%
df_edi = pd.DataFrame(edi_info)
df_edi.tail()
# Out:
#         가게명     구                                       주소
# 702  연희삼거리점  서대문구                    서울 서대문구 연희로 117 (연희동)
# 703   이화여대점  서대문구             서울 서대문구 이화여대길 26 (대현동, 이화빌딩)
# 704  충정로3가점  서대문구  서울 서대문구 경기대로 26-26 (충정로3가, 더스타일하우스디센트럴)
# 705  홍은사거리점  서대문구            서울 서대문구 통일로 510 (홍은동, 북한산 더샵)
# 706    홍제역점  서대문구                              서울 서대문구 홍제동

# %%
star_count = []
for item in gu_list:
    n = len(df_star.loc[df_star['구']==item])
    data = {
        "구" : item,
        "스벅 매장수" : n
    }
    star_count.append(data)
df_star_count = pd.DataFrame(star_count)
df_star_count
# Out:
#        구  스벅 매장수
# 0   동대문구       9
# 1    구로구      12
# 2    강남구      89
# 3    성북구      15
# 4    강북구       6
# 5   영등포구      41
# 6    송파구      34
# 7    서초구      48
# 8    노원구      13
# 9    성동구      13
# 10   강서구      26
# 11   마포구      35
# 12   관악구      12
# 13   광진구      19
# 14   은평구      10
# 15   용산구      24
# 16   금천구      13
# 17   도봉구       4
# 18   중랑구       7
# 19    중구      53
# 20   양천구      17
# 21   동작구      11
# 22   종로구      39
# 23  서대문구      21
# 24   강동구      17

# %%
edi_count = []
for item in gu_list:
    n = len(df_edi.loc[df_edi['구']==item])
    data = {
        "구" : item,
        "이디야 매장수" : n
    }
    edi_count.append(data)
df_edi_count = pd.DataFrame(edi_count)
df_edi_count
# Out:
#        구  이디야 매장수
# 0   동대문구       25
# 1    구로구       28
# 2    강남구       44
# 3    성북구       32
# 4    강북구       20
# 5   영등포구       41
# 6    송파구       39
# 7    서초구       29
# 8    노원구       62
# 9    성동구        0
# 10   강서구       52
# 11   마포구       38
# 12   관악구       28
# 13   광진구       24
# 14   은평구       27
# 15   용산구       14
# 16   금천구       23
# 17   도봉구       24
# 18   중랑구       27
# 19    중구       29
# 20   양천구       27
# 21   동작구       22
# 22   종로구       31
# 23  서대문구       21
# 24   강동구        0

# %%
sum_data = pd.merge(df_edi_count, df_star_count)
sum_data["매장 수 차이"] = sum_data["이디야 매장수"] - sum_data["스벅 매장수"]
sum_data
# Out:
#        구  이디야 매장수  스벅 매장수  매장 수 차이
# 0   동대문구       25       9       16
# 1    구로구       28      12       16
# 2    강남구       44      89      -45
# 3    성북구       32      15       17
# 4    강북구       20       6       14
# 5   영등포구       41      41        0
# 6    송파구       39      34        5
# 7    서초구       29      48      -19
# 8    노원구       62      13       49
# 9    성동구        0      13      -13
# 10   강서구       52      26       26
# 11   마포구       38      35        3
# 12   관악구       28      12       16
# 13   광진구       24      19        5
# 14   은평구       27      10       17
# 15   용산구       14      24      -10
# 16   금천구       23      13       10
# 17   도봉구       24       4       20
# 18   중랑구       27       7       20
# 19    중구       29      53      -24
# 20   양천구       27      17       10
# 21   동작구       22      11       11
# 22   종로구       31      39       -8
# 23  서대문구       21      21        0
# 24   강동구        0      17      -17

# %%
from matplotlib import rc
import matplotlib.font_manager as fm

fm.get_fontconfig_fonts()

# 디렉토리 및 파일 이름에 맞추어 변경
font_location = './NanumGothic.ttf'

font_name = fm.FontProperties(fname=font_location).get_name()
rc('font', family=font_name)
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_7108\3681494351.py:4: MatplotlibDeprecationWarning:
# The get_fontconfig_fonts function was deprecated in Matplotlib 3.5 and will be removed two minor releases later.
#   fm.get_fontconfig_fonts()

# %%
import matplotlib.font_manager as fm

# 설치된 폰트 출력
font_list = [font.name for font in fm.fontManager.ttflist]
font_list
# Out:
# ['cmb10',
#  'cmss10',
#  'DejaVu Serif',
#  'STIXNonUnicode',
#  'DejaVu Sans',
#  'cmsy10',
#  'STIXGeneral',
#  'DejaVu Sans Mono',
#  'STIXNonUnicode',
#  'DejaVu Sans',
#  'STIXSizeOneSym',
#  'STIXGeneral',
#  'STIXSizeFiveSym',
#  'STIXSizeTwoSym',
#  'STIXSizeTwoSym',
#  'DejaVu Serif Display',
#  'cmr10',
#  'DejaVu Serif',
#  'STIXSizeOneSym',
#  'STIXNonUnicode',
#  'DejaVu Serif',
#  'STIXGeneral',
#  'cmmi10',
#  'STIXGeneral',
#  'DejaVu Sans Display',
#  'DejaVu Sans Mono',
#  'DejaVu Sans Mono',
#  'cmex10',
#  'STIXSizeFourSym',
#  'DejaVu Sans Mono',
#  'DejaVu Sans',
#  'STIXSizeThreeSym',
#  'STIXSizeThreeSym',
#  'DejaVu Sans',
#  'DejaVu Serif',
#  'STIXNonUnicode',
#  'STIXSizeFourSym',
#  'cmtt10',
#  'Lucida Handwriting',
#  'Courier New',
#  'Berlin Sans FB Demi',
#  'Elephant',
#  'Franklin Gothic Heavy',
#  'Yu Gothic',
#  'Old English Text MT',
#  'Imprint MT Shadow',
#  'Magic R',
#  'Microsoft Himalaya',
#  'Script MT Bold',
#  'Bodoni MT',
#  'Microsoft Tai Le',
#  'Palatino Linotype',
#  'Bookman Old Style',
#  'Onyx',
#  'Georgia',
#  'MS Reference Sans Serif',
#  'Symbol',
#  'Ebrima',
#  'Tw Cen MT Condensed',
#  'Segoe UI Historic',
#  'Playbill',
#  'Poor Richard',
#  'Microsoft JhengHei',
#  'HYGungSo-Bold',
#  'Rockwell Condensed',
#  'Perpetua',
#  'MoeumT R',
#  'Arial',
#  'Constantia',
#  'Century Schoolbook',
#  'Franklin Gothic Heavy',
#  'Leelawadee UI',
#  'Sylfaen',
#  'Californian FB',
#  'Corbel',
#  'Century Gothic',
#  'Gadugi',
#  'Trebuchet MS',
#  'Franklin Gothic Medium',
#  'Garamond',
#  'Segoe UI',
#  'Dubai',
#  'HYGothic-Medium',
#  'MingLiU-ExtB',
#  'Segoe UI Emoji',
#  'Century',
#  'Consolas',
#  'Haettenschweiler',
#  'Corbel',
#  'Candara',
#  'Century',
#  'Courier New',
#  'Trebuchet MS',
#  'Bodoni MT',
#  'Segoe UI',
#  'Rage Italic',
#  'Malgun Gothic',
#  'Nirmala UI',
#  'Eras Demi ITC',
#  'Sitka',
#  'Candara',
#  'Corbel',
#  'Baskerville Old Face',
#  'Franklin Gothic Demi',
#  'Bernard MT Condensed',
#  'Monotype Corsiva',
#  'Agency FB',
#  'Ebrima',
#  'Calibri',
#  'Comic Sans MS',
#  'Edwardian Script ITC',
#  'Calibri',
#  'Segoe Script',
#  'Verdana',
#  'Lucida Sans Typewriter',
#  'Malgun Gothic',
#  'Ink Free',
#  'Segoe Print',
#  'Microsoft Yi Baiti',
#  'Onyx',
#  'Bell MT',
#  'Impact',
#  'Candara',
#  'Myanmar Text',
#  'Georgia',
#  'SimSun',
#  'Curlz MT',
#  'Informal Roman',
#  'HoloLens MDL2 Assets',
#  'Bodoni MT',
#  'Arial',
#  'Bookman Old Style',
#  'Century Gothic',
#  'Microsoft New Tai Lue',
#  'Verdana',
#  'Playbill',
#  'Book Antiqua',
#  'Consolas',
#  'Tw Cen MT',
#  'Old English Text MT',
#  'Dubai',
#  'Bodoni MT',
#  'Calisto MT',
#  'Brush Script MT',
#  'Gill Sans MT Ext Condensed Bold',
#  'Bodoni MT',
#  'MV Boli',
#  'Gulim',
#  'Segoe Print',
#  'Vivaldi',
#  'Book Antiqua',
#  'Franklin Gothic Medium Cond',
#  'Lucida Sans Typewriter',
#  'Consolas',
#  'Lucida Bright',
#  'Javanese Text',
#  'Yu Gothic',
#  'Verdana',
#  'Yu Gothic',
#  'Courier New',
#  'Dubai',
#  'Segoe UI Historic',
#  'Cambria',
#  'Franklin Gothic Demi',
#  'Gigi',
#  'Arial',
#  'Corbel',
#  'Lucida Bright',
#  'SimSun-ExtB',
#  'Calibri',
#  'Tw Cen MT Condensed',
#  'High Tower Text',
#  'Perpetua',
#  'Bodoni MT',
#  'Perpetua',
#  'Berlin Sans FB',
#  'HYPost-Light',
#  'Niagara Engraved',
#  'Franklin Gothic Heavy',
#  'Comic Sans MS',
#  'Constantia',
#  'Pyunji R',
#  'Castellar',
#  'Lucida Bright',
#  'Gill Sans MT',
#  'Nirmala UI',
#  'Bahnschrift',
#  'Gill Sans MT Condensed',
#  'Gill Sans MT',
#  'Century Gothic',
#  'Bradley Hand ITC',
#  'Gadugi',
#  'Times New Roman',
#  'Lucida Sans Typewriter',
#  'Segoe UI',
#  'Microsoft JhengHei',
#  'Century Schoolbook',
#  'Gadugi',
#  'HYSinMyeongJo-Medium',
#  'Tw Cen MT',
#  'Verdana',
#  'Segoe UI',
#  'Showcard Gothic',
#  'Perpetua Titling MT',
#  'Stencil',
#  'Bodoni MT',
#  'Franklin Gothic Demi',
#  'Magic R',
#  'Bernard MT Condensed',
#  'Palace Script MT',
#  'Rockwell',
#  'Tw Cen MT Condensed',
#  'Rockwell',
#  'Verdana',
#  'Colonna MT',
#  'Vladimir Script',
#  'Batang',
#  'Georgia',
#  'Courier New',
#  'Microsoft Tai Le',
#  'Microsoft Sans Serif',
#  'Calibri',
#  'MS Gothic',
#  'Bookman Old Style',
#  'Trebuchet MS',
#  'HYMyeongJo-Extra',
#  'Tw Cen MT',
#  'Arial',
#  'Copperplate Gothic Light',
#  'Webdings',
#  'Times New Roman',
#  'Gill Sans MT',
#  'Palatino Linotype',
#  'Constantia',
#  'Tahoma',
#  'Lucida Console',
#  'Sylfaen',
#  'Garamond',
#  'Microsoft Himalaya',
#  'Segoe UI',
#  'MS Reference Sans Serif',
#  'Lucida Sans',
#  'Eras Demi ITC',
#  'Dubai',
#  'Eras Bold ITC',
#  'Bahnschrift',
#  'Yu Gothic',
#  'Berlin Sans FB',
#  'Microsoft Yi Baiti',
#  'Bookman Old Style',
#  'Tw Cen MT Condensed Extra Bold',
#  'Malgun Gothic',
#  'Gill Sans MT',
#  'HYShortSamul-Medium',
#  'Copperplate Gothic Bold',
#  'Book Antiqua',
#  'Lucida Bright',
#  'Bell MT',
#  'Corbel',
#  'Nirmala UI',
#  'Perpetua',
#  'Goudy Old Style',
#  'Courier New',
#  'Calibri',
#  'Goudy Old Style',
#  'Tw Cen MT Condensed Extra Bold',
#  'Snap ITC',
#  'Segoe UI',
#  'Segoe UI',
#  'Papyrus',
#  'Edwardian Script ITC',
#  'Ink Free',
#  'Cascadia Code',
#  'Arial',
#  'HYPost-Medium',
#  'Kristen ITC',
#  'Garamond',
#  'Ebrima',
#  'Franklin Gothic Medium',
#  'Consolas',
#  'Arial',
#  'OCR A Extended',
#  'Dubai',
#  'Palatino Linotype',
#  'Imprint MT Shadow',
#  'Microsoft YaHei',
#  'Palace Script MT',
#  'Dubai',
#  'Rockwell Condensed',
#  'Segoe UI',
#  'Palatino Linotype',
#  'Candara',
#  'Arial Rounded MT Bold',
#  'Gigi',
#  'Segoe UI',
#  'Microsoft YaHei',
#  'Bell MT',
#  'Gloucester MT Extra Condensed',
#  'Trebuchet MS',
#  'Candara',
#  'Trebuchet MS',
#  'Forte',
#  'Californian FB',
#  'Comic Sans MS',
#  'Cooper Black',
#  'Yu Gothic',
#  'Calibri',
#  'Bodoni MT',
#  'Footlight MT Light',
#  'SimSun-ExtB',
#  'Parchment',
#  'Lucida Fax',
#  'Parchment',
#  'Candara',
#  'Segoe UI Symbol',
#  'Footlight MT Light',
#  'Showcard Gothic',
#  'Calisto MT',
#  'Century Schoolbook',
#  'Arial',
#  'Leelawadee UI',
#  'Gill Sans MT Condensed',
#  'Gill Sans MT',
#  'Ami R',
#  'Eras Medium ITC',
#  'Cooper Black',
#  'Calisto MT',
#  'Eras Light ITC',
#  'Wingdings 2',
#  'Batang',
#  'Eras Bold ITC',
#  'Century Gothic',
#  'Lucida Sans Typewriter',
#  'Microsoft YaHei',
#  'Lucida Sans Typewriter',
#  'Arial',
#  'Century Schoolbook',
#  'Wingdings 2',
#  'Engravers MT',
#  'Perpetua Titling MT',
#  'Arial',
#  'Lucida Calligraphy',
#  'Georgia',
#  'Ami R',
#  'HYSinMyeongJo-Medium',
#  'Leelawadee UI',
#  'Berlin Sans FB Demi',
#  'Wingdings',
#  'Goudy Old Style',
#  'Bell MT',
#  'Baskerville Old Face',
#  'Rockwell Condensed',
#  'Lucida Bright',
#  'Lucida Fax',
#  'Lucida Sans',
#  'Arial',
#  'Rockwell',
#  'Segoe Script',
#  'Microsoft YaHei',
#  'HYPMokGak-Bold',
#  'Calibri',
#  'Gulim',
#  'Georgia',
#  'Calibri',
#  'Britannic Bold',
#  'Calibri',
#  'Tempus Sans ITC',
#  'Bodoni MT',
#  'Segoe UI',
#  'Lucida Sans Typewriter',
#  'Cambria',
#  'Matura MT Script Capitals',
#  'Calisto MT',
#  'Segoe UI',
#  'Candara',
#  'Nirmala UI',
#  'Corbel',
#  'Book Antiqua',
#  'Yet R',
#  'Script MT Bold',
#  'Stencil',
#  'Corbel',
#  'Niagara Engraved',
#  'Book Antiqua',
#  'HYGothic-Medium',
#  'Arial',
#  'Segoe UI',
#  'Perpetua',
#  'Georgia',
#  'Bodoni MT',
#  'Cascadia Code',
#  'High Tower Text',
#  'Constantia',
#  'Bookshelf Symbol 7',
#  'Juice ITC',
#  'Gloucester MT Extra Condensed',
#  'Microsoft JhengHei',
#  'Bauhaus 93',
#  'Segoe UI Emoji',
#  'Californian FB',
#  'Arial',
#  'Segoe Script',
#  'Lucida Sans Typewriter',
#  'Bell MT',
#  'Berlin Sans FB',
#  'Leelawadee UI',
#  'Tempus Sans ITC',
#  'Franklin Gothic Book',
#  'Lucida Sans Unicode',
#  'Engravers MT',
#  'Gabriola',
#  'Candara',
#  'Sitka',
#  'Colonna MT',
#  'Arial',
#  'Blackadder ITC',
#  'Symbol',
#  'Microsoft PhagsPa',
#  'Elephant',
#  'Calibri',
#  'Malgun Gothic',
#  'Palatino Linotype',
#  'Lucida Fax',
#  'Kunstler Script',
#  'Harlow Solid Italic',
#  'Cambria',
#  'Segoe UI',
#  'Agency FB',
#  'Segoe UI Variable',
#  'Century Schoolbook',
#  'Chiller',
#  'Kunstler Script',
#  'Juice ITC',
#  'Bookshelf Symbol 7',
#  'Agency FB',
#  'HYPost-Medium',
#  'Pyunji R',
#  'Yu Gothic',
#  'Trebuchet MS',
#  'Rockwell',
#  'Centaur',
#  'MS Outlook',
#  'Segoe Script',
#  'Modern No. 20',
#  'Javanese Text',
#  'Britannic Bold',
#  'Rockwell',
#  'Microsoft PhagsPa',
#  'Candara',
#  'MS Reference Specialty',
#  'HYPost-Light',
#  'Century Gothic',
#  'Gill Sans MT',
#  'Century Gothic',
#  'Myanmar Text',
#  'Rockwell Condensed',
#  'Eras Light ITC',
#  'MS Gothic',
#  'Bodoni MT',
#  'Lucida Sans',
#  'Harrington',
#  'Bookman Old Style',
#  'Bell MT',
#  'Times New Roman',
#  'SimSun',
#  'Corbel',
#  'Tw Cen MT Condensed',
#  'Leelawadee UI',
#  'Algerian',
#  'Elephant',
#  'Corbel',
#  'Courier New',
#  'Segoe UI',
#  'Lucida Fax',
#  'Bookman Old Style',
#  'Curlz MT',
#  'Segoe MDL2 Assets',
#  'HYHeadLine-Medium',
#  'Magneto',
#  'Berlin Sans FB',
#  'Times New Roman',
#  'Malgun Gothic',
#  'Georgia',
#  'Leelawadee UI',
#  'Perpetua Titling MT',
#  'Consolas',
#  'Rockwell Extra Bold',
#  'Niagara Solid',
#  'Cascadia Mono',
#  'Microsoft Sans Serif',
#  'Times New Roman',
#  'Franklin Gothic Demi Cond',
#  'Microsoft JhengHei',
#  'Lucida Sans Unicode',
#  'MoeumT R',
#  'Freestyle Script',
#  'Centaur',
#  'Tw Cen MT',
#  'Microsoft YaHei',
#  'Lucida Calligraphy',
#  'Ebrima',
#  'Comic Sans MS',
#  'Microsoft New Tai Lue',
#  'Wide Latin',
#  'Arial',
#  'Calibri',
#  'Tahoma',
#  'Bodoni MT',
#  'HYGraphic-Medium',
#  'Rockwell',
#  'Gill Sans MT Ext Condensed Bold',
#  'Microsoft Tai Le',
#  'Gill Sans Ultra Bold',
#  'Bookman Old Style',
#  'Segoe Print',
#  'Monotype Corsiva',
#  'Webdings',
#  'Vivaldi',
#  'Lucida Sans',
#  'Bodoni MT',
#  'Arial',
#  'Verdana',
#  'Bauhaus 93',
#  'Century Schoolbook',
#  'Bookman Old Style',
#  'Goudy Old Style',
#  'Elephant',
#  'Castellar',
#  'Garamond',
#  'Headline R',
#  'Viner Hand ITC',
#  'High Tower Text',
#  'Segoe UI',
#  'Segoe MDL2 Assets',
#  'Wingdings 3',
#  'Maiandra GD',
#  'Copperplate Gothic Light',
#  'Century Gothic',
#  'Perpetua',
#  'Mongolian Baiti',
#  'MV Boli',
#  'HYGothic-Extra',
#  'Nirmala UI',
#  'Lucida Sans',
#  'Lucida Sans Typewriter',
#  'Century Gothic',
#  'Segoe UI',
#  'Tahoma',
#  'Bradley Hand ITC',
#  'Myanmar Text',
#  'Mongolian Baiti',
#  'Georgia',
#  'OCR A Extended',
#  'Segoe UI',
#  'Constantia',
#  'Comic Sans MS',
#  'Poor Richard',
#  'Lucida Sans',
#  'HoloLens MDL2 Assets',
#  'Candara',
#  'Comic Sans MS',
#  'Cascadia Mono',
#  'Tw Cen MT',
#  'Wingdings',
#  'Nirmala UI',
#  'Segoe UI',
#  'Cambria',
#  'Dubai',
#  'Segoe Print',
#  'Franklin Gothic Medium',
#  'Gabriola',
#  'Segoe UI Symbol',
#  'Rage Italic',
#  'Snap ITC',
#  'Calisto MT',
#  'Pristina',
#  'Maiandra GD',
#  'Impact',
#  'HYGothic-Extra',
#  'Felix Titling',
#  'MingLiU-ExtB',
#  'Bodoni MT',
#  'Calibri',
#  'Segoe UI',
#  'Franklin Gothic Demi',
#  'Haettenschweiler',
#  'Algerian',
#  'Perpetua',
#  'Garamond',
#  'Headline R',
#  'Bodoni MT',
#  'Mistral',
#  'Arial',
#  'Candara',
#  'Microsoft Tai Le',
#  'Book Antiqua',
#  'Lucida Handwriting',
#  'Mistral',
#  'Magneto',
#  'HYPMokGak-Bold',
#  'Lucida Fax',
#  'Microsoft PhagsPa',
#  'HYShortSamul-Medium',
#  'High Tower Text',
#  'Gill Sans Ultra Bold Condensed',
#  'HYMyeongJo-Extra',
#  'Cambria',
#  'Informal Roman',
#  'Microsoft YaHei',
#  'HYHeadLine-Medium',
#  'Franklin Gothic Medium Cond',
#  'Palatino Linotype',
#  'Microsoft PhagsPa',
#  'Cambria',
#  'Palatino Linotype',
#  'Lucida Sans',
#  'Bodoni MT',
#  'Ravie',
#  'Courier New',
#  'Segoe UI',
#  'Dubai',
#  'Modern No. 20',
#  'Franklin Gothic Book',
#  'Microsoft JhengHei',
#  'NanumSquare',
#  'Franklin Gothic Heavy',
#  'Gill Sans Ultra Bold',
#  'Verdana',
#  'Broadway',
#  'Bodoni MT',
#  'Brush Script MT',
#  'Calisto MT',
#  'Rockwell',
#  'Times New Roman',
#  'Vladimir Script',
#  'Lucida Fax',
#  'Lucida Sans',
#  'Myanmar Text',
#  'Constantia',
#  'Franklin Gothic Book',
#  'Californian FB',
#  'Corbel',
#  'Pristina',
#  'Segoe UI',
#  'Blackadder ITC',
#  'Calisto MT',
#  'Century Schoolbook',
#  'Lucida Console',
#  'Lucida Bright',
#  'Comic Sans MS',
#  'Trebuchet MS',
#  'Tw Cen MT',
#  'Arial Rounded MT Bold',
#  'Lucida Bright',
#  'Segoe UI Variable',
#  'Bodoni MT',
#  'Bodoni MT',
#  'Segoe Fluent Icons',
#  'Yet R',
#  'New Gulim',
#  'Chiller',
#  'MT Extra',
#  'HYGraphic-Medium',
#  'Lucida Fax',
#  'Harrington',
#  'Verdana',
#  'Rockwell Extra Bold',
#  'Microsoft New Tai Lue',
#  'Goudy Stout',
#  'Segoe UI',
#  'Franklin Gothic Book',
#  'Constantia',
#  'Goudy Old Style',
#  'Gill Sans MT',
#  'Corbel',
#  'Freestyle Script',
#  'Broadway',
#  'Eras Medium ITC',
#  'Book Antiqua',
#  'Felix Titling',
#  'Sitka',
#  'Palatino Linotype',
#  'MS Reference Specialty',
#  'Garamond',
#  'Ravie',
#  'Niagara Solid',
#  'Cambria',
#  'French Script MT',
#  'Calisto MT',
#  'Cambria',
#  'Comic Sans MS',
#  'Century Schoolbook',
#  'Yu Gothic',
#  'Wingdings 3',
#  'Segoe UI',
#  'Bodoni MT',
#  'Trebuchet MS',
#  'Jokerman',
#  'Constantia',
#  'Segoe UI',
#  'Jokerman',
#  'Copperplate Gothic Bold',
#  'Candara',
#  'Courier New',
#  'Rockwell',
#  'Malgun Gothic',
#  'Arial',
#  'Lucida Fax',
#  'Californian FB',
#  'Franklin Gothic Medium',
#  'Microsoft New Tai Lue',
#  'Bodoni MT',
#  'Corbel',
#  'Bodoni MT',
#  'Sitka',
#  'Times New Roman',
#  'Arial',
#  'New Gulim',
#  'Forte',
#  'Gadugi',
#  'Consolas',
#  'Franklin Gothic Demi Cond',
#  'Times New Roman',
#  'MT Extra',
#  'Matura MT Script Capitals',
#  'HYGungSo-Bold',
#  'Gill Sans MT',
#  'Segoe Fluent Icons',
#  'Gill Sans Ultra Bold Condensed',
#  'Marlett',
#  'Tahoma',
#  'Agency FB',
#  'Microsoft JhengHei',
#  'Tw Cen MT',
#  'Harlow Solid Italic',
#  'Perpetua Titling MT',
#  'Consolas',
#  'Goudy Stout',
#  'Papyrus',
#  'Book Antiqua',
#  'Californian FB',
#  'Perpetua',
#  'Wide Latin',
#  'Goudy Old Style',
#  'Yu Gothic',
#  'Viner Hand ITC',
#  'Lucida Bright',
#  'Tw Cen MT',
#  'Consolas',
#  'Kristen ITC',
#  'French Script MT',
#  'MS Outlook']

# %%
# 음수 표시가 개져서 나올 때
import matplotlib as mpl
mpl.rcParams['axes.unicode_minus']=False

# %%
a = sum_data["매장 수 차이"]
y = "ediya"

plt.rcParams['font.family'] = 'Malgun Gothic'
plt.figure(figsize=(20,15))
plt.bar(sum_data["구"], a, color = 'b', label ="이디야 기준 매장수 차이" )
plt.title("구별 이디야, 스타벅스 매장수 차이", fontsize = 20)
plt.xlabel("구", fontsize = 20)
plt.legend(loc ='lower left', fontsize = 20)
plt.show()
